# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
  
# Read Images
def draw_outdoors():
    img = mpimg.imread('/Users/hottestgirlonearth/Desktop/North-Cascades-National-Park-Lake-Ann-park.webp')
    return img

# Output Images
plt.imshow(img)
